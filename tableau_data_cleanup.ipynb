# %%
import pandas as pd

# %%
filepath2020 = "JC-202005-citibike-tripdata.csv"

filepath2021 = "JC-202105-citibike-tripdata.csv"

df_2020 = pd.read_csv(filepath2020)
df_2021 = pd.read_csv(filepath2021)

# %%
df_2020.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1           138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2           229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3           261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4           168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
#
#    start station id          start station name  start station latitude  \
# 0              3195                     Sip Ave               40.730897
# 1              3792  Columbus Dr at Exchange Pl               40.716870
# 2              3483               Montgomery St               40.719420
# 3              3278            Monmouth and 6th               40.725685
# 4              3194             McGinley Square               40.725340
#
#    start station longitude  end station id end station name  \
# ...

# %%
df_2021.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
df_2020.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df_2021.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
cleandf_2020 = df_2020.drop(columns=["birth year", "gender"])

# %%
cleandf_2020.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype'],
#       dtype='object')

# %%
cleandf_2020.rename(columns={"starttime": "started_at", "stoptime":"ended_at", "start station id":"start_station_id", "start station name": "start_station_name", "start station latitude":"start_lat", "start station longitude":"start_lng", "end station latitude":"end_lat", "end station longitude":"end_lng", "end station name":"end_station_name", "end station id":"end_station_id"}, inplace=True)

# %%
cleandf_2020.dtypes
# Out:
# tripduration            int64
# started_at             object
# ended_at               object
# start_station_id        int64
# start_station_name     object
# start_lat             float64
# start_lng             float64
# end_station_id          int64
# end_station_name       object
# end_lat               float64
# end_lng               float64
# bikeid                  int64
# usertype               object
# dtype: object

# %%
df_2021.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
cleandf_2020.head()
# Out:
#    tripduration                started_at                  ended_at  \
# 0           349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1           138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2           229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3           261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4           168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
#
#    start_station_id          start_station_name  start_lat  start_lng  \
# 0              3195                     Sip Ave  40.730897 -74.063913
# 1              3792  Columbus Dr at Exchange Pl  40.716870 -74.032810
# 2              3483               Montgomery St  40.719420 -74.050990
# 3              3278            Monmouth and 6th  40.725685 -74.048790
# 4              3194             McGinley Square  40.725340 -74.067622
#
#    end_station_id end_station_name    end_lat    end_lng  bikeid    usertype
# ...

# %%
cleandf_2020["start_date"] = pd.to_datetime(cleandf_2020['started_at']).dt.date
cleandf_2020["start_time"] = pd.to_datetime(cleandf_2020['started_at']).dt.time

cleandf_2020["end_date"] = pd.to_datetime(cleandf_2020['ended_at']).dt.date
cleandf_2020["end_time"] = pd.to_datetime(cleandf_2020['ended_at']).dt.time

# %%
cleandf_2020
# Out:
#        tripduration                started_at                  ended_at  \
# 0               349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1               138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2               229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3               261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4               168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
# ...             ...                       ...                       ...
# 25072           395  2020-05-31 23:35:50.9460  2020-05-31 23:42:26.5300
# 25073          1681  2020-05-31 23:38:30.8240  2020-06-01 00:06:32.0360
# 25074          1657  2020-05-31 23:39:07.2680  2020-06-01 00:06:44.5740
# 25075           420  2020-05-31 23:45:28.3290  2020-05-31 23:52:28.3680
# 25076            87  2020-05-31 23:50:55.8390  2020-05-31 23:52:23.0920
#
#        start_station_id          start_station_name  start_lat  start_lng  \
# ...

# %%
df_2021.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
df_2021["start_date"] = pd.to_datetime(df_2021['started_at']).dt.date
df_2021["start_time"] = pd.to_datetime(df_2021['started_at']).dt.time

df_2021["end_date"] = pd.to_datetime(df_2021['ended_at']).dt.date
df_2021["end_time"] = pd.to_datetime(df_2021['ended_at']).dt.time

df_2021.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
df_2021["year"] = 2021

# %%
df_2021
# Out:
#                 ride_id rideable_type           started_at  \
# 0      74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00
# 1      58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47
# 2      1429D912C16EEE59   docked_bike  2021-05-25 16:19:34
# 3      FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19
# 4      B88D37626F000BBA   docked_bike  2021-05-14 09:48:34
# ...                 ...           ...                  ...
# 45038  62FF3FEDAAD7FCB3   docked_bike  2021-05-31 12:46:22
# 45039  E742AEA7068E0E4A   docked_bike  2021-05-31 16:34:19
# 45040  E769F9EE96D6433A   docked_bike  2021-05-17 22:52:35
# 45041  EC973614DCA179A2   docked_bike  2021-05-31 20:48:58
# 45042  3571180FE5C52CB1   docked_bike  2021-05-23 14:28:43
#
#                   ended_at             start_station_name start_station_id  \
# 0      2021-05-23 18:38:21  9 St HBLR - Jackson St & 8 St            HB305
# 1      2021-05-31 16:55:28  9 St HBLR - Jackson St & 8 St            HB305
# ...

# %%
cleandf_2020["year"] = 2020

# %%
cleandf_2020.head()
# Out:
#    tripduration                started_at                  ended_at  \
# 0           349  2020-05-01 00:09:45.5860  2020-05-01 00:15:35.2930
# 1           138  2020-05-01 01:11:22.5280  2020-05-01 01:13:41.2460
# 2           229  2020-05-01 05:31:29.5350  2020-05-01 05:35:19.2400
# 3           261  2020-05-01 05:51:39.3960  2020-05-01 05:56:00.9370
# 4           168  2020-05-01 06:06:31.9510  2020-05-01 06:09:20.1410
#
#    start_station_id          start_station_name  start_lat  start_lng  \
# 0              3195                     Sip Ave  40.730897 -74.063913
# 1              3792  Columbus Dr at Exchange Pl  40.716870 -74.032810
# 2              3483               Montgomery St  40.719420 -74.050990
# 3              3278            Monmouth and 6th  40.725685 -74.048790
# 4              3194             McGinley Square  40.725340 -74.067622
#
#    end_station_id end_station_name    end_lat    end_lng  bikeid    usertype  \
# ...

# %%
cleandf_2020.columns
# Out:
# Index(['tripduration', 'started_at', 'ended_at', 'start_station_id',
#        'start_station_name', 'start_lat', 'start_lng', 'end_station_id',
#        'end_station_name', 'end_lat', 'end_lng', 'bikeid', 'usertype',
#        'start_date', 'start_time', 'end_date', 'end_time', 'year'],
#       dtype='object')

# %%
df_2021.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'start_date', 'start_time', 'end_date', 'end_time',
#        'year'],
#       dtype='object')

# %%
test_df = df_2021
test_df.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  74A4206E7487CBC9   docked_bike  2021-05-23 16:51:00  2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike  2021-05-31 16:54:47  2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike  2021-05-25 16:19:34  2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike  2021-05-22 17:32:19  2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike  2021-05-14 09:48:34  2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
test_df[["started_at", "ended_at"]] = test_df[["started_at", "ended_at"]].apply(pd.to_datetime)

# %%
# t1 = pd.to_datetime(test_df["started_at"])
# t2 = pd.to_datetime(test_df["ended_at"])

# test_df["tripduration"] = pd.Timedelta(t2 - t1).seconds/60.0

test_df['tripduration'] = (test_df.ended_at - test_df.started_at)

# %%
test_df.head()
# Out:
#             ride_id rideable_type          started_at            ended_at  \
# 0  74A4206E7487CBC9   docked_bike 2021-05-23 16:51:00 2021-05-23 18:38:21
# 1  58EEE2950FFE01CE   docked_bike 2021-05-31 16:54:47 2021-05-31 16:55:28
# 2  1429D912C16EEE59   docked_bike 2021-05-25 16:19:34 2021-05-25 17:03:06
# 3  FE9C5B74167CBCCD   docked_bike 2021-05-22 17:32:19 2021-05-22 17:41:27
# 4  B88D37626F000BBA   docked_bike 2021-05-14 09:48:34 2021-05-14 10:17:36
#
#               start_station_name start_station_id  \
# 0  9 St HBLR - Jackson St & 8 St            HB305
# 1  9 St HBLR - Jackson St & 8 St            HB305
# 2  9 St HBLR - Jackson St & 8 St            HB305
# 3  9 St HBLR - Jackson St & 8 St            HB305
# 4                       Union St            JC051
#
#                 end_station_name end_station_id  start_lat  start_lng  \
# 0  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# 1  9 St HBLR - Jackson St & 8 St          HB305  40.747907 -74.038411
# ...

# %%
cleandf_2020[["started_at", "ended_at"]] = cleandf_2020[["started_at", "ended_at"]].apply(pd.to_datetime)
cleandf_2020['tripduration_1'] = (cleandf_2020.ended_at - cleandf_2020.started_at)

# %%
cleandf_2020.columns
# Out:
# Index(['tripduration', 'started_at', 'ended_at', 'start_station_id',
#        'start_station_name', 'start_lat', 'start_lng', 'end_station_id',
#        'end_station_name', 'end_lat', 'end_lng', 'bikeid', 'usertype',
#        'start_date', 'start_time', 'end_date', 'end_time', 'year',
#        'tripduration_1'],
#       dtype='object')

# %%
cleandf_2020.rename({"tripduration": "tripduration(secs)", "tripduration_1": "tripduration"}, inplace=True)

# %%
cleandf_2020
# Out:
#        tripduration              started_at                ended_at  \
# 0               349 2020-05-01 00:09:45.586 2020-05-01 00:15:35.293
# 1               138 2020-05-01 01:11:22.528 2020-05-01 01:13:41.246
# 2               229 2020-05-01 05:31:29.535 2020-05-01 05:35:19.240
# 3               261 2020-05-01 05:51:39.396 2020-05-01 05:56:00.937
# 4               168 2020-05-01 06:06:31.951 2020-05-01 06:09:20.141
# ...             ...                     ...                     ...
# 25072           395 2020-05-31 23:35:50.946 2020-05-31 23:42:26.530
# 25073          1681 2020-05-31 23:38:30.824 2020-06-01 00:06:32.036
# 25074          1657 2020-05-31 23:39:07.268 2020-06-01 00:06:44.574
# 25075           420 2020-05-31 23:45:28.329 2020-05-31 23:52:28.368
# 25076            87 2020-05-31 23:50:55.839 2020-05-31 23:52:23.092
#
#        start_station_id          start_station_name  start_lat  start_lng  \
# 0                  3195                     Sip Ave  40.730897 -74.063913
# ...

# %%
cleandf_2020.columns
# Out:
# Index(['tripduration', 'started_at', 'ended_at', 'start_station_id',
#        'start_station_name', 'start_lat', 'start_lng', 'end_station_id',
#        'end_station_name', 'end_lat', 'end_lng', 'bikeid', 'usertype',
#        'start_date', 'start_time', 'end_date', 'end_time', 'year',
#        'tripduration_1'],
#       dtype='object')

# %%
df_2020_ids = cleandf_2020.reset_index()

# %%
df_2020_ids.rename(columns={"index": "ride_id", "tripduration":"tripduration(secs)", "tripduration_1": "tripduration"}, inplace=True)

# %%
df_2021.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual', 'start_date', 'start_time', 'end_date', 'end_time',
#        'year', 'tripduration'],
#       dtype='object')

# %%
df_2020_ids.columns
# Out:
# Index(['ride_id', 'tripduration(secs)', 'started_at', 'ended_at',
#        'start_station_id', 'start_station_name', 'start_lat', 'start_lng',
#        'end_station_id', 'end_station_name', 'end_lat', 'end_lng', 'bikeid',
#        'usertype', 'start_date', 'start_time', 'end_date', 'end_time', 'year',
#        'tripduration'],
#       dtype='object')

# %%
clean_df_2021 = df_2021[["ride_id", "start_station_id", "start_station_name", "start_lat", "start_lng", "end_station_id", "end_station_name", "end_lat", "end_lng", "started_at", "ended_at", "start_date", "start_time", "end_date", "end_time", "tripduration", "year"]]

clean_df_2021
# Out:
#                 ride_id start_station_id             start_station_name  \
# 0      74A4206E7487CBC9            HB305  9 St HBLR - Jackson St & 8 St
# 1      58EEE2950FFE01CE            HB305  9 St HBLR - Jackson St & 8 St
# 2      1429D912C16EEE59            HB305  9 St HBLR - Jackson St & 8 St
# 3      FE9C5B74167CBCCD            HB305  9 St HBLR - Jackson St & 8 St
# 4      B88D37626F000BBA            JC051                       Union St
# ...                 ...              ...                            ...
# 45038  62FF3FEDAAD7FCB3            HB303              Clinton St & 7 St
# 45039  E742AEA7068E0E4A            HB303              Clinton St & 7 St
# 45040  E769F9EE96D6433A            JC077                    Astor Place
# 45041  EC973614DCA179A2            HB303              Clinton St & 7 St
# 45042  3571180FE5C52CB1            HB303              Clinton St & 7 St
#
#        start_lat  start_lng end_station_id               end_station_name  \
# ...

# %%
df_2020_ids.columns
# Out:
# Index(['ride_id', 'tripduration(secs)', 'started_at', 'ended_at',
#        'start_station_id', 'start_station_name', 'start_lat', 'start_lng',
#        'end_station_id', 'end_station_name', 'end_lat', 'end_lng', 'bikeid',
#        'usertype', 'start_date', 'start_time', 'end_date', 'end_time', 'year',
#        'tripduration'],
#       dtype='object')

# %%
clean_df_2020_ids = df_2020_ids[["ride_id", "start_station_id", "start_station_name", "start_lat", "start_lng", "end_station_id", "end_station_name", "end_lat", "end_lng", "started_at", "ended_at", "start_date", "start_time", "end_date", "end_time", "tripduration", "year"]]

clean_df_2020_ids
# Out:
#        ride_id  start_station_id          start_station_name  start_lat  \
# 0            0              3195                     Sip Ave  40.730897
# 1            1              3792  Columbus Dr at Exchange Pl  40.716870
# 2            2              3483               Montgomery St  40.719420
# 3            3              3278            Monmouth and 6th  40.725685
# 4            4              3194             McGinley Square  40.725340
# ...        ...               ...                         ...        ...
# 25072    25072              3202                Newport PATH  40.727224
# 25073    25073              3199                Newport Pkwy  40.728745
# 25074    25074              3199                Newport Pkwy  40.728745
# 25075    25075              3195                     Sip Ave  40.730897
# 25076    25076              3272                Jersey & 3rd  40.723332
#
#        start_lng  end_station_id  end_station_name    end_lat    end_lng  \
# ...

# %%
combined_df = pd.concat
